# %%
from IPython.display import HTML

# %%
HTML("""

<style>
    .page {
        font-family: "Trebuchet MS", Arial, sans-serif;
        background-color: #454a52;
        color: #d4d6d9;
        padding: 40px;
    }

    /* Navigation Bar */
    .navbar {
        position: fixed;
        top: 0;
        left: 0;
        width: 100%;
        background-color: #265e39;
        display: flex;
        justify-content: center;
        gap: 40px;
        padding: 18px 0;
        box-shadow: 0 3px 8px rgba(0,0,0,.3);
        z-index: 1000;
    }

    .navbar a {
        color: #d4d6d9 !important;
        text-decoration: none;
        font-size: 22px;
        font-weight: bold;
        padding: 10px 18px;
        border-radius: 8px;
        transition: background-color .3s ease,
                    color .3s ease,
                    transform .2s ease;
    }

    .navbar a:hover {
        background-color: #3d8c59;
        transform: translateY(-2px);
    }

    .navbar a.active {
        background-color: #4ca96a;
    }

    .button-container {
        display: flex;       
        gap: 30px;           
        justify-content: center; 
        color: green;
    }

    .button-container button {
        font-size: 20px;
        padding: 40px 50px;  
        cursor: pointer;   
    }

    .image-container {
        display: flex;       
        gap: 15px;           
    }

</style>

<div class="navbar">
    <a class="active" href="http://localhost:8866/voila/render/home.ipynb">Home</a>
    <a href="http://localhost:8866/voila/render/dataset.ipynb">Dataset</a>
    <a href="http://localhost:8866/voila/render/modeling.ipynb">Modeling</a>
    <a href="http://localhost:8866/voila/render/maps.ipynb">Forecast Maps</a>
    <a href="http://localhost:8866/voila/render/summary.ipynb">Summary</a>
</div>

<div class="page">
<h1 style="font-size: 80px; text-align: center"><b>PalmWatch</b></h1>


<h1 style="font-size: 50px">Conclusion</h1>

<p style="font-size: 25px">
    Through machine learning models, forecasting deforestation demonstrates the large fraction of deforestation across Sumatra, especially due to palm oil. Countless indigenous lives and wildlife across the island are at risk of losing their home, giving a visualization of the dangers of the palm oil industry. 
</p>

<h1 style="font-size: 50px">Acknowledgments</h1>

<p style="font-size: 25px">
    We would like to thank our research lead Dr. Mario Bañuelos, our project mentor Dr. Meghan Hutch, our teaching assistant Nikhil Sharma, M.S., our mentor Dr. Varada Shevade, and our data provider David Jacobson. 
</p>

<div class="image-container" style="display: flex; justify-content: center; gap: 30px; align-items: center;">
    <div class="image-box">
        <img src="https://datascience.uchicago.edu/wp-content/uploads/2025/12/tall-dsi-logo.png" width="500">
    </div>
    <div class="image-box">
        <img src="https://www.inclusivedevelopment.net/wp-content/uploads/2020/03/IDI-Logo-RGB-Teal.png" width="500">
    </div>
</div>

</div>


""")
# Out:
# <style>
#     .page {
#         font-family: "Trebuchet MS", Arial, sans-serif;
#         background-color: #454a52;
#         color: #d4d6d9;
#         padding: 40px;
#     }
#
#     /* Navigation Bar */
#     .navbar {
#         position: fixed;
#         top: 0;
#         left: 0;
#         width: 100%;
#         background-color: #265e39;
#         display: flex;
#         justify-content: center;
#         gap: 40px;
#         padding: 18px 0;
#         box-shadow: 0 3px 8px rgba(0,0,0,.3);
#         z-index: 1000;
#     }
#
#     .navbar a {
#         color: #d4d6d9 !important;
#         text-decoration: none;
#         font-size: 22px;
#         font-weight: bold;
#         padding: 10px 18px;
#         border-radius: 8px;
#         transition: background-color .3s ease,
#                     color .3s ease,
#                     transform .2s ease;
#     }
#
#     .navbar a:hover {
#         background-color: #3d8c59;
#         transform: translateY(-2px);
#     }
#
#     .navbar a.active {
#         background-color: #4ca96a;
#     }
#
#     .button-container {
#         display: flex;
#         gap: 30px;
#         justify-content: center;
#         color: green;
#     }
#
#     .button-container button {
#         font-size: 20px;
#         padding: 40px 50px;
#         cursor: pointer;
#     }
#
#     .image-container {
#         display: flex;
#         gap: 15px;
#     }
#
# </style>
#
# <div class="navbar">
#     <a class="active" href="http://localhost:8866/voila/render/home.ipynb">Home</a>
#     <a href="http://localhost:8866/voila/render/dataset.ipynb">Dataset</a>
#     <a href="http://localhost:8866/voila/render/modeling.ipynb">Modeling</a>
#     <a href="http://localhost:8866/voila/render/maps.ipynb">Forecast Maps</a>
#     <a href="http://localhost:8866/voila/render/summary.ipynb">Summary</a>
# </div>
#
# <div class="page">
# <h1 style="font-size: 80px; text-align: center"><b>PalmWatch</b></h1>
#
#
# <h1 style="font-size: 50px">Conclusion</h1>
#
# <p style="font-size: 25px">
#     Through machine learning models, forecasting deforestation demonstrates the large fraction of deforestation across Sumatra, especially due to palm oil. Countless indigenous lives and wildlife across the island are at risk of losing their home, giving a visualization of the dangers of the palm oil industry.
# </p>
#
# <h1 style="font-size: 50px">Acknowledgments</h1>
#
# <p style="font-size: 25px">
#     We would like to thank our research lead Dr. Mario Bañuelos, our project mentor Dr. Meghan Hutch, our teaching assistant Nikhil Sharma, M.S., our mentor Dr. Varada Shevade, and our data provider David Jacobson.
# </p>
#
# <div class="image-container" style="display: flex; justify-content: center; gap: 30px; align-items: center;">
#     <div class="image-box">
#         <img src="https://datascience.uchicago.edu/wp-content/uploads/2025/12/tall-dsi-logo.png" width="500">
#     </div>
#     <div class="image-box">
#         <img src="https://www.inclusivedevelopment.net/wp-content/uploads/2020/03/IDI-Logo-RGB-Teal.png" width="500">
#     </div>
# </div>
#
# </div>
