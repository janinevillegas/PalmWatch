# %%
# %pip install voila
# %pip install IPython.display
# Out:
# Requirement already satisfied: voila in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (0.5.12)
# Requirement already satisfied: jupyter-client<9,>=7.4.4 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from voila) (8.9.1)
# Requirement already satisfied: jupyter-core>=4.11.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from voila) (5.9.1)
# Requirement already satisfied: jupyter-server<3,>=1.18 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from voila) (2.20.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from voila) (2.28.0)
# Requirement already satisfied: nbclient>=0.4.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from voila) (0.11.0)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from voila) (7.17.1)
# Requirement already satisfied: traitlets<6,>=5.0.3 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from voila) (5.15.1)
# Requirement already satisfied: websockets>=9.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from voila) (17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-client<9,>=7.4.4->voila) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=25.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-client<9,>=7.4.4->voila) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-client<9,>=7.4.4->voila) (6.4.2)
# Requirement already satisfied: typing-extensions>=4.13.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-client<9,>=7.4.4->voila) (4.16.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-core>=4.11.0->voila) (4.11.0)
# Requirement already satisfied: anyio>=3.1.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (4.14.2)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (3.1.6)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (5.10.4)
# Requirement already satisfied: packaging>=22.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (26.2)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (0.26.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-server<3,>=1.18->voila) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.15.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.26.0)
# Requirement already satisfied: requests>=2.31 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.34.2)
# Requirement already satisfied: beautifulsoup4 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (4.15.0)
# Requirement already satisfied: bleach!=5.0.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (6.4.0)
# Requirement already satisfied: defusedxml in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (3.3.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from nbconvert<8,>=6.4.5->voila) (2.20.0)
# Requirement already satisfied: idna>=2.8 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.18->voila) (3.18)
# Requirement already satisfied: argon2-cffi-bindings in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (25.1.0)
# Requirement already satisfied: webencodings in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (1.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (2026.6.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=1.18->voila) (2.22.1)
# Requirement already satisfied: six>=1.5 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client<9,>=7.4.4->voila) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2026.7.22)
# Requirement already satisfied: ptyprocess in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from terminado>=0.8.3->jupyter-server<3,>=1.18->voila) (0.7.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.9.1)
# Requirement already satisfied: fqdn in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.5.1)
# Requirement already satisfied: isoduration in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.1.0)
# Requirement already satisfied: uri-template in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (2.1.0)
# Requirement already satisfied: pycparser in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (3.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.4.0)
# Requirement already satisfied: tzdata in /Users/janine/Documents/DSSI/Project/PalmWatch/.venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (2026.3)
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement IPython.display (from versions: none)
# ERROR: No matching distribution found for IPython.display
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
HTML("""

<style>
    .page {
        font-family: "Trebuchet MS", Arial, sans-serif;
        background-color: #454a52;
        color: #d4d6d9;
        padding: 40px;
    }

    .button-container {
        display: flex;       
        gap: 30px;           
        justify-content: center; 
        color: green;
    }

    .button-container button {
        font-size: 20px;
        padding: 40px 50px;  
        cursor: pointer;   
    }

    .image-container {
        display: flex;       
        gap: 15px;           
    }

</style>

<div class="page">
<h1 style="font-size: 80px; text-align: center"><b>PalmWatch</b></h1>


<h1 style="font-size: 50px">Findings and Conclusion</h1>

<p style="font-size: 25px">In collaboration with the University of Chicago's Data Science Institute and Inclusive Development International,
Palm Watch maps the palm oil supply chains of the world's largest consumer brands to identify the social and enviornmental impacts 
of oil palm cultivation. 

PalmWatch received support from the 11th Hour Project, Bread for the World, and Heinrich Böll Stiftung Southeast Asia Regional Office.
</p>

<h1 style="font-size: 50px">Our Project</h1>

<p style="font-size: 25px">
    Currently, PalmWatch looks at deforestation retrospectively, documenting forest loss that has already happened. However, in order to keep major corporations accountable
    of their deforestation efforts, this project aims to forecast deforestation on the island of Sumatra. Sumatra, Indonesia harvests 60% of the world's palm oil, making it
    a critical area to monitor. By forecasting deforestation across Sumatra, we can identify the areas that are most at risk of deforestation, and how much is caused my palm-drive loss.
</p>


<div class="button-container">

    <button type="button" style="background-color: #4b965d">
        Our Dataset
    </button>

    <button type="button" style="background-color: #4b965d">
        Modeling
    </button>
    
    <a href="voila/render/maps.ipynb">
        <button type="button" style="background-color: #4b965d">
            Forecasted Deforestation Maps
        </button>
    </a>

    <a href="voila/render/summary.ipynb">
        <button type="button" style="background-color: #4b965d">
            Summary and References
        </button>
    </a>
</div>
</div>


""")
