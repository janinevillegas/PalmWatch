# %%
# %pip install voila
# %pip install IPython.display

# %%
from IPython.display import HTML

# %%
HTML(""""" 

<h1 style="font-size: 80px; text-align: center">Introduction To Our Dataset</h1>
<div style="text-align: center">
    <img src="https://upload.wikimedia.org/wikipedia/commons/7/73/WV_Sumatra_map_PNG.png?utm_source=en.wikivoyage.org&utm_campaign=index&utm_content=original" width="800"></img>
</div>
<p style="font-size: 15px; text-align: center"> Image Source: en.wikivoyage.org </p>


<h2 style="font-size: 40px; text-align: left">Where is our data from?</h2>

<p style="font-size: 25px"> Our data was provided by David Jacobson, a Data and Engineering Manager at the Data Science Institute. 
</p> 

<h2 style="font-size: 40px; text-align: left">What does it look like?</h2>
<p style="font-size: 25px"> 
The island of Sumatra is divided into a grid of equal-size hexagonal cells (~41 km^2 each) using satellite imagery. 
<br></br>
<br>For every cell (8,708 unique hex IDs) and for each year from 2000-2018, the dataset records:</br>

<ul>
<li>The province it belongs to </li>
<li>Initial size of forest</li>
<li>Amount cleared</li>
<li>Amount of forest damaged</li>
<li>Amount remaining</li>
<li>Neighboring cells forest history</li>

</ul>
</p>

""")
# Out:
# ""
#
# <h1 style="font-size: 80px; text-align: center">Introduction To Our Dataset</h1>
# <div style="text-align: center">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/7/73/WV_Sumatra_map_PNG.png?utm_source=en.wikivoyage.org&utm_campaign=index&utm_content=original" width="800"></img>
# </div>
# <p style="font-size: 15px; text-align: center"> Image Source: en.wikivoyage.org </p>
#
#
# <h2 style="font-size: 40px; text-align: left">Where is our data from?</h2>
#
# <p style="font-size: 25px"> Our data was provided by David Jacobson, a Data and Engineering Manager at the Data Science Institute.
# </p>
#
# <h2 style="font-size: 40px; text-align: left">What does it look like?</h2>
# <p style="font-size: 25px">
# The island of Sumatra is divided into a grid of equal-size hexagonal cells (~41 km^2 each) using satellite imagery.
# <br></br>
# <br>For every cell (8,708 unique hex IDs) and for each year from 2000-2018, the dataset records:</br>
#
# <ul>
# ...
