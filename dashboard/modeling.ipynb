# %%
# %pip install voila
# %pip install IPython.display
# Out:
# ...
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.5 MB ? eta -:--:--
#    ------------------------------ --------- 3.4/4.5 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.5/4.5 MB 8.1 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/6 [websockets]
#    ---------------------------------------- 0/6 [websockets]
#    -------------------------- ------------- 4/6 [isoduration]
#    --------------------------------- ------ 5/6 [voila]
#    --------------------------------- ------ 5/6 [voila]
#    --------------------------------- ------ 5/6 [voila]
#    ---------------------------------------- 6/6 [voila]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
from IPython.display import HTML

# %%
HTML("""""
<h1 style="font-size: 80px; text-align: center">Models Used</h1>

<style>
        .button-container {
            display: flex;       
            gap: 30px;           
            justify-content: center; 
        }

        .button-container button {
            font-size: 20px;
            padding: 40px 50px;  /
            cursor: pointer;    
        }

</style>

<div style="text-align: center">
    <img src="https://truthout.org/app/uploads/2019/12/IMG_0006smaller.jpg" width="800"></img>
</div>

<p>""</p>




""")
# Out:
# ""
# <h1 style="font-size: 80px; text-align: center">Models Used</h1>
#
# <style>
#         .button-container {
#             display: flex;
#             gap: 30px;
#             justify-content: center;
#         }
#
#         .button-container button {
#             font-size: 20px;
#             padding: 40px 50px;  /
#             cursor: pointer;
#         }
#
# </style>
#
# <div style="text-align: center">
#     <img src="https://truthout.org/app/uploads/2019/12/IMG_0006smaller.jpg" width="800"></img>
# </div>
#
# <p>"What is PalmWatch?"</p>
#
# <div class="button-container">
#     <button type="button">
#         Modeling
#     </button>
#
#     <a href="voila/render/maps.ipynb">
#         <button type="button">
#             Forecasted Deforestation Maps
#         </button>
#     </a>
#
#     <button type="button">
#         Summary and References
#     </button>
# </div
