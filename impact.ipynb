# %%
from IPython.display import HTML

# %%
HTML("""

<style>
    .page {
        font-family: "Trebuchet MS", Arial, sans-serif;
        background-color: #454a52;
        color: #d4d6d9;
        padding: 40px;
        min-height: 100vh;
    }

    /* Navigation Bar */
    .navbar {
        position: fixed;
        top: 0;
        left: 0;
        width: 100%;
        background-color: #265e39;
        display: flex;
        justify-content: center;
        gap: 40px;
        padding: 18px 0;
        box-shadow: 0 3px 8px rgba(0,0,0,.3);
        z-index: 1000;
    }

    .navbar a {
        color: #d4d6d9 !important;
        text-decoration: none;
        font-size: 22px;
        font-weight: bold;
        padding: 10px 18px;
        border-radius: 8px;
        transition: background-color .3s ease,
                    color .3s ease,
                    transform .2s ease;
    }

    .navbar a:hover {
        background-color: #3d8c59;
        transform: translateY(-2px);
    }

    .navbar a.active {
        background-color: #4ca96a;
    }

    .button-container {
        display: flex;       
        gap: 30px;           
        justify-content: center; 
        color: #265e39;
    }

    .button-container button {
        font-size: 20px;
        padding: 40px 50px;  
        cursor: pointer;   
    }

    .image-container {
        display: flex;       
        gap: 15px;           
    }

</style>

<div class="navbar">
    <a class="active" href="http://localhost:8866/voila/render/home.ipynb">Home</a>
    <a href="http://localhost:8866/voila/render/dataset.ipynb">Dataset</a>
    <a href="http://localhost:8866/voila/render/modeling.ipynb">Modeling</a>
    <a href="http://localhost:8866/voila/render/maps.ipynb">Forecast Maps</a>
    <a href="http://localhost:8866/voila/render/summary.ipynb">Summary</a>
    <a href="http://localhost:8866/voila/render/impact.ipynb">Impact</a>
</div>

<div class="page">
    <h1 style="font-size: 80px; text-align: center"><b>Impact</b></h1>
    <div style="text-align: center">
        <img src="https://www.hrw.org/sites/default/files/styles/16x9_xxl/public/multimedia_images_2019/201909wrd_indonesia_main.jpg?itok=kmDZq6zZ" width="800"></img>
    </div>
    <p style="font-size: 15px; text-align: center"> Image Source: https://www.hrw.org/report/2019/09/23/when-we-lost-forest-we-lost-everything/oil-palm-plantations-and-rights-violations </p>

    <h1 style="font-size: 50px; text-align: center"><b>Indigenous Communities</b></h1>

    <p style="font-size: 25px">
        In a case study done by Human Rights Watch in 2019, countless Indigenous communities throughout Indonesia lost their livelihood due to oil palm plantations. 
        When looking at Sumatra, the vast landscape of oil palm plantions drove off communities who've lived their for hundreds of years. The Orang Rimba, a semi-nomadic 
        forest-dependent Indigenous group native to central Sumatra faced the brunt of the expansion of oil palm plantations throughout the island.

        <br></br>
        In Indonesia, weak laws have been exacerbated by poor goverment oversight, forcing oil palm plantation companies to fail in fulfilling their human rights oats and 
        due diligence responsibilities. This major loss of land and livelihodo became a drastic change in life for people living in the province of Jambi.

        <br></br>

        Without goverment reforms, either legislative or increased oversight, Indigenous communties face the bare brunt of oil palm plantations' impact and risk losing their 
        distinct identity. The lack of reforms stunt these communities' intrinsic relationship with their enviornment, forcing them to fall at risk to lose their culture, language, 
        knowledge, and unique tranditions. Successive governments throughout Indonesia begin to turn a blind eye to the widespread forest clearance, facilitating proliferation of oil palm
        plantations. 

        <br></br>

        Between 2001 to 2017, Indonesia lost 24 million hectacres of forest cover; however, damage is further aggravated by the lack of plans to preserve what little land remains. Groups like the
        Orang Rimba are left to live in abject poverty, where many of them are homeless, living in plastic tents without livelihood support. A community whom has been self-sufficient for generations are
        now reduced to beginning on the highway, or even "stealing" oil palm fruits fromt he plantation area to sell and make money. However, very few adults are employed by these oil palm plantation owners,
        leaving most to remain in poverty. 

    </p>

    <h1 style="font-size: 50px; text-align: center"><b>Wildlife</b></h1>
    <div style="text-align: center">
        <img src="https://savingnature.com/wp-content/uploads/2020/04/shutterstock_233602363.webp" width="800"></img>
    </div>
    <p style="font-size: 15px; text-align: center"> Image Source: https://savingnature.com/sumatra-orangutans/ </p>

    <p style="font-size: 25px">
        Across Sumatra, the large scale deforestation has made a large impact to wildlife across the island. Rainforests have been
        cleared to make way for new oil palm plantations, destroying precious homes and habitats for countless wildlife such as orangutans, rhinoceros, and tigers.
        However, more advances in the Indonesian governmental policies and corporate commitments have been effective; however with the large scale demand to continue
        oil palm plantations expansion, it greatly impacts wildlife across the island. 

        <br></br>

        Orangutans have been facing a range of threats, losing countless amount of forest for their habitats. However, due to illegal logging, even protected areas face
        danger within the rapidly growing palm oil industry. As Sumatra is home to several of the country's largest national parks, many whose been destoryed due to illegally making palm
        oil. Various species of elephants and orangutans are facing dangerously high rates of extinction due to the loss of their habitat, creating a lack of variety for the species who are 
        currently inhabiting it. 
    </p>

    <div class="image-container" style="display: flex; justify-content: center; gap: 30px; align-items: center;">
        <div class="image-box">
            <img src="https://datascience.uchicago.edu/wp-content/uploads/2025/12/tall-dsi-logo.png" width="500">
        </div>
        <div class="image-box">
            <img src="https://www.inclusivedevelopment.net/wp-content/uploads/2020/03/IDI-Logo-RGB-Teal.png" width="500">
        </div>
    </div>

</div>


""")
