# %%
from IPython.display import HTML

# %%
HTML("""

<style>
    .page {
        font-family: "Trebuchet MS", Arial, sans-serif;
        background-color: #454a52;
        color: #d4d6d9;
        padding: 40px;
        min-height: 100vh;
    }

    /* Navigation Bar */
    .navbar {
        position: fixed;
        top: 0;
        left: 0;
        width: 100%;
        background-color: #265e39;
        display: flex;
        justify-content: center;
        gap: 40px;
        padding: 18px 0;
        box-shadow: 0 3px 8px rgba(0,0,0,.3);
        z-index: 1000;
    }

    .navbar a {
        color: #d4d6d9 !important;
        text-decoration: none;
        font-size: 22px;
        font-weight: bold;
        padding: 10px 18px;
        border-radius: 8px;
        transition: background-color .3s ease,
                    color .3s ease,
                    transform .2s ease;
    }

    .navbar a:hover {
        background-color: #3d8c59;
        transform: translateY(-2px);
    }

    .navbar a.active {
        background-color: #4ca96a;
    }

    .button-container {
        display: flex;       
        gap: 30px;           
        justify-content: center; 
        color: #265e39;
    }

    .button-container button {
        font-size: 20px;
        padding: 40px 50px;  
        cursor: pointer;   
    }

    .image-container {
        display: flex;       
        gap: 15px;           
    }

</style>

<div class="navbar">
    <a class="active" href="http://localhost:8866/voila/render/home.ipynb">Home</a>
    <a href="http://localhost:8866/voila/render/dataset.ipynb">Dataset</a>
    <a href="http://localhost:8866/voila/render/modeling.ipynb">Modeling</a>
    <a href="http://localhost:8866/voila/render/maps.ipynb">Forecast Maps</a>
    <a href="http://localhost:8866/voila/render/summary.ipynb">Summary</a>
    <a href="http://localhost:8866/voila/render/impact.ipynb">Impact</a>
</div>

<div class="page">
    <h1 style="font-size: 80px; text-align: center"><b>PalmWatch</b></h1>
    <div style="text-align: center">
        <img src="https://truthout.org/app/uploads/2019/12/IMG_0006smaller.jpg" width="800"></img>
    </div>

    <div class="image-container" style="display: flex; justify-content: center; gap: 30px; align-items: center;">
        <div class="image-box">
            <img src="https://datascience.uchicago.edu/wp-content/uploads/2025/12/tall-dsi-logo.png" width="500">
        </div>
        <div class="image-box">
            <img src="https://www.inclusivedevelopment.net/wp-content/uploads/2020/03/IDI-Logo-RGB-Teal.png" width="500">
        </div>
    </div>



    <h1 style="font-size: 50px">What is PalmWatch?</h1>

    <p style="font-size: 25px">In collaboration with the University of Chicago's Data Science Institute and Inclusive Development International,
    Palm Watch maps the palm oil supply chains of the world's largest consumer brands to identify the social and enviornmental impacts 
    of oil palm cultivation. 

    PalmWatch received support from the 11th Hour Project, Bread for the World, and Heinrich Böll Stiftung Southeast Asia Regional Office.
    </p>

    <h1 style="font-size: 50px">Our Project</h1>

    <p style="font-size: 25px">
        Currently, PalmWatch looks at deforestation retrospectively, documenting forest loss that has already happened. However, in order to keep major corporations accountable
        of their deforestation efforts, this project aims to forecast deforestation on the island of Sumatra. Sumatra, Indonesia harvests 60% of the world's palm oil, making it
        a critical area to monitor. By forecasting deforestation across Sumatra, we can identify the areas that are most at risk of deforestation, and how much is caused my palm-driven loss.
    </p>


</div>


""")
# Out:
# <style>
#     .page {
#         font-family: "Trebuchet MS", Arial, sans-serif;
#         background-color: #454a52;
#         color: #d4d6d9;
#         padding: 40px;
#         min-height: 100vh;
#     }
#
#     /* Navigation Bar */
#     .navbar {
#         position: fixed;
#         top: 0;
#         left: 0;
#         width: 100%;
#         background-color: #265e39;
#         display: flex;
#         justify-content: center;
#         gap: 40px;
#         padding: 18px 0;
#         box-shadow: 0 3px 8px rgba(0,0,0,.3);
#         z-index: 1000;
#     }
#
#     .navbar a {
#         color: #d4d6d9 !important;
#         text-decoration: none;
#         font-size: 22px;
#         font-weight: bold;
#         padding: 10px 18px;
#         border-radius: 8px;
#         transition: background-color .3s ease,
#                     color .3s ease,
#                     transform .2s ease;
#     }
#
#     .navbar a:hover {
#         background-color: #3d8c59;
# ...
